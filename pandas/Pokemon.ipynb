# %% [markdown]
# # Pandas

# %%
import pandas as pd

#Read the csv file and assign the content to 'poke_data' variable
data = pd.read_csv('Pokemon.csv')    

#let's try to print first 3 rows to control
print(data.head(3))

print("---------------------------------")


#This looks better:
data.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# ---------------------------------
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
#If it is an excel file then type 
#data_xlsx = pd.read_excel('Pokemon.xlsx')

#txt files
# data_txt = pd.read_csv('Pokemon.txt', delimiter = '\t')
#you can custom delimeter parameter

# %%
#Read The column labels
print(data.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Read a specific column
print(data['Type 1'][0:6])

print("---------------------------------")

#Read a specific column 2
print(data.Defense[0:12])

print("----------------------------------")

#Read columns
print(data[['Name', 'Type 1', 'Attack']].head(6))
# Out:
# 0    Grass
# 1    Grass
# 2    Grass
# 3    Grass
# 4     Fire
# 5     Fire
# Name: Type 1, dtype: object
# ---------------------------------
# 0      49
# 1      63
# 2      83
# 3     123
# 4      43
# 5      58
# 6      78
# 7     111
# 8      78
# 9      65
# 10     80
# 11    100
# Name: Defense, dtype: int64
# ----------------------------------
#                     Name Type 1  Attack
# 0              Bulbasaur  Grass      49
# 1                Ivysaur  Grass      62
# 2               Venusaur  Grass      82
# 3  VenusaurMega Venusaur  Grass     100
# 4             Charmander   Fire      52
# 5             Charmeleon   Fire      64

# %%
#Specified row
print(data.iloc[2]) 

print("----------------------------------")

#Specified rows
print(data.iloc[[0,2]]) 

print("----------------------------------")

#specify (row,column)
print(data.iloc[2,1])
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ----------------------------------
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 2     80           1      False
# ----------------------------------
# Venusaur

# %%
#Access group of values using labels
data.loc[data['Type 2'] == "Poison"]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 16    13                 Weedle    Bug  Poison    195   40      35       30
# 17    14                 Kakuna    Bug  Poison    205   45      25       50
# 18    15               Beedrill    Bug  Poison    395   65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Poison    495   65     150       40
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# ...

# %%
#Generate descriptive statistics
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
#Sorting values
data.sort_values('Total', ascending=False)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                    ...      ...       ...    ...  ...     ...
# 13    10               Caterpie      Bug       NaN    195   45      30
# 288  265                Wurmple      Bug       NaN    195   45      45
# 446  401              Kricketot      Bug       NaN    194   37      25
# 322  298                Azurill   Normal     Fairy    190   50      20
# 206  191                Sunkern    Grass       NaN    180   30      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
data.sort_values(['Total', 'Attack'], ascending=[False, 1])
#You can use 1 or 0 instead of True or False
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                    ...      ...       ...    ...  ...     ...
# 16    13                 Weedle      Bug    Poison    195   40      35
# 288  265                Wurmple      Bug       NaN    195   45      45
# 446  401              Kricketot      Bug       NaN    194   37      25
# 322  298                Azurill   Normal     Fairy    190   50      20
# 206  191                Sunkern    Grass       NaN    180   30      30
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making Changes

# %%
#Changing and assigning value
data['Total'] = data['HP'] + data['Attack'] + data['Defense'] + data['Sp. Atk'] + data['Sp. Def'] + data['Speed']

#Alternative


data.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
#Dropping some columns
#tThat returns DataFrame without the removed index or column labels.
df = data.drop(columns = ['Total', 'Defense'])
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Grass  Poison  45      49       65       65
# 1  2                Ivysaur  Grass  Poison  60      62       80       80
# 2  3               Venusaur  Grass  Poison  80      82      100      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      122      120
# 4  4             Charmander   Fire     NaN  39      52       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data['Total'] = data.iloc[:, 4:10].sum(axis=1)
data.head(7)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    591  45      49       49
# 1  2                Ivysaur  Grass  Poison    750  60      62       63
# 2  3               Venusaur  Grass  Poison    970  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison   1170  80     100      123
# 4  4             Charmander   Fire     NaN    553  39      52       43
# 5  5             Charmeleon   Fire     NaN    730  58      64       58
# 6  6              Charizard   Fire  Flying    968  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# ...

# %%
#Write object to a csv file.
#data.to_csv('modified.csv', index=False)

#Write object to an Excel sheet.
#data.to_excel('modified.xlsx', index=False)

#Write object to a txt file.
#data.to_csv('modified.txt', index=False, sep = '\t')

# %%
#Compute mean of groups, excluding missing values
data.groupby(['Type 1']).mean()
# Out:
#                    #        Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754   696.173913  56.884058   70.971014   70.724638
# Dark      461.354839   815.322581  66.806452   88.387097   70.225806
# Dragon    474.375000  1018.031250  83.312500  112.125000   86.375000
# Electric  363.500000   802.318182  59.795455   69.090909   66.295455
# Fairy     449.529412   777.764706  74.117647   61.529412   65.705882
# Fighting  363.851852   766.814815  69.851852   96.777778   65.925926
# Fire      327.403846   841.711538  69.903846   84.769231   67.769231
# Flying    677.750000   867.500000  70.750000   78.750000   66.250000
# Ghost     486.500000   814.781250  64.437500   73.781250   81.187500
# Grass     344.871429   780.357143  67.271429   73.214286   70.800000
# Ground    356.281250   811.093750  73.781250   95.750000   84.843750
# Ice       423.541667   803.458333  72.000000   72.750000   71.416667
# ...

# %%
#Compute count of group, excluding missing values.
data['count'] = 6

data.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
#Return TextFileReader object for iteration - chunksize
#for data in pd.read_csv('Pokemon.csv', chunksize = 20000):
    #print("\n************************************************\n")
    #print(data)
